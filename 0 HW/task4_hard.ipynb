# %% [markdown]
# # <a href="https://mipt-stats.gitlab.io/courses/ad_fivt.html">Введение в анализ данных</a>
# ## Домашнее задание 4. Регрессия и классификация. <font color="orange"><i>Сложная часть</i></font>

# %% [markdown]
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
# * Выполненную работу нужно отправить телеграм-боту `@miptstats_ad21_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. **Работы, присланные иным способом, не принимаются.**
# * Дедлайн см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно ноутбук в формате ipynb.
# * Теоретические задачи необходимо прислать одним из следующих способов:
#   * фотографией в правильной ориентации, где все четко видно, а почерк разборчив;
#   * фотографией, **встроенной в ноутбук** посредством `Edit -> Insert Image`;
#   * в виде $LaTeX$ в markdown-ячейках.
# * Теоретические задачи не проверяются, если какое-то требование не выполнено. Особенно внимательно все проверьте в случае выбора второго пункта. Неправильно вставленные фотографии могут не передаться при отправке.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания будут сдавать устный зачет.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Для выполнения задания используйте этот ноутбук в качестве основы, ничего не удаляя из него. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
#
# **Баллы за задание:**
#
# <b><font color="blue">Легкая часть</font></b> (достаточно на "хор"):
# * Задача 1 &mdash; 3 балла
# * Задача 2 &mdash; 6 баллов
# * Задача 3 &mdash; 2 балла
#
# <b><font color="orange">Сложная часть</font></b> (необходимо на "отл"):
# * Задача 4 &mdash; 2 балла
# * Задача 5 &mdash; 5 баллов
# * Задача 6 &mdash; 5 баллов
# * Задача 7 &mdash; 3 балла

# %% [markdown]
# ### <font color="blue"><i>Легкая часть</i></font>
#
# Условие <b><font color="blue">легкой части</font></b> расположено по <a href="https://mipt-stats.gitlab.io/courses/ad_fivt/task4_easy.html">ссылке</a>.

# %% [markdown]
# ### <font color="orange"><i>Сложная часть</i></font>

# %% [markdown]
# ### Задача 4.
# Пусть $\mathscr{X} = \mathbb{R}^2$ — пространство признаков, $\mathscr{Y} = \{0, 1\}$ — множество классов. Рассматривается квадратичный дискриминантный анализ. Условное распределение $X$ при условии $Y=k$ равно $\mathcal{N}(a_k, \Sigma_k)$. Приведите примеры таких параметров $a_k, \Sigma_k$ и вероятностей $\mathsf{P}(Y = k)$, при которых разделяющая поверхность является
# * гиперболой;
# * параболой;
# * двумя параллельными прямыми;
# * двумя пересекающимися прямыми.

# %% [markdown]
# ![-yeukk042gfw2jnnt-1.png](attachment:-yeukk042gfw2jnnt-1.png)

# %% [markdown]
# ![-yeukk042gfw2jnnt-2.png](attachment:-yeukk042gfw2jnnt-2.png)

# %% [markdown]
# ### Задача 5.
#
# Как можно было увидеть ранее, оценки коэффициентов становятся слишком большими при наличии некоторых проблем с данными. Чтобы этого не происходило, часто выполняют процедуру *регуляризации* в модели.
#
# Пусть $X \in \mathbb{R}^{n \times d}$ &mdash; матрица признаков, $Y \in \mathbb{R}^{n}$ &mdash; вектор значений целевого признака, $\theta \in \mathbb{R}^{d}$ &mdash; неизвестный вектор параметров. В методе наименьших квадратов решается задача
# $$\| Y - X\theta \|^2 \longrightarrow \min_\theta.$$
# Регуляризация заключается в искусственном усечении значений вектора оценок коэффициентов путем добавления его нормы к оптимизируемому функционалу. Тем самым решается задача
# $$\| Y - X\theta \|^2 + \lambda \| \theta \|^2 \longrightarrow \min_\theta,$$
# где $\lambda > 0$ &mdash; гиперпараметр модели, то есть число, которое задается пользователем. Такая модель называется **Ridge-регрессией**.
#
# **1.** Найдите оценку $\theta$ в модели ridge-регрессии. Сравните ее с оценкой коэффициентов в методе наименьших квадратов. Помогает ли она избавиться от "проблемы" МНК, которая обсуждалась на занятии?

# %% [markdown]
# **2.** Выпишите формулу поиска оценки коэффициентов методом стохастического градиентного спуска для модели ridge-регрессии.

# %% [markdown]
# **3.** Многие модели машинного обучения требуют *стандартизацию признаков*. Существует множество различных способов стандартизации, из которых наиболее распространены два следующих.
# 1. <a target="_blank" href="https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html"><it>StandardScaler</it></a>. Пусть $x_{ij}$ &mdash; значение признака $j$ для объекта $i$. Обозначим $m_j$ &mdash; выборочное среднее значение признака $j$, а $s^2_j$ &mdash; выборочную дисперсию признака $j$. Тогда стандартизацией является преобразование
# $$\widetilde{x}_{ij} = \frac{x_{ij} - m_j}{s_j}.$$
# 2. <a target="_blank" href="https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html"><it>MinMaxScaler</it></a>. Пусть $x_{ij}$ &mdash; значение признака $j$ для объекта $i$. Обозначим $m_j$ и $M_j$ &mdash; минимальное и максимальное значения признака $j$ соответственно. Тогда стандартизацией является преобразование
# $$\widetilde{x}_{ij} = \frac{x_{ij} - m_j}{M_j - m_j}.$$
#
# Для метода наименьших квадратов стандартизацию признаков можно не производить, однако для модели ridge-регрессии стандартизация необходима. Поясните это. Можно представить, что признаки имеют некоторые различные единицы измерения.

# %% [markdown]
# ![-zfr0mdgk7eqegyyv-1.png](attachment:-zfr0mdgk7eqegyyv-1.png)

# %% [markdown]
# ![-zfr0mdgk7eqegyyv-2.png](attachment:-zfr0mdgk7eqegyyv-2.png)

# %% [markdown]
# ### Задача 6.
#
# В данной задаче мы продолжим анализировать данные велопроката из <a href="https://mipt-stats.gitlab.io/courses/ad_fivt/task4_easy.html#Задача-2.">задачи 2</a>.
#
# ![ubike.png](attachment:ubike.png)
#
# Для начала реализуйте класс для работы с моделью ridge-регрессии. Интерфейс этого класса соответствует стандарту библиотеки `sklearn`, который использует также множество других библиотек.

# %%
import scipy.stats as sps
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.3, palette='Set2')

import warnings
warnings.simplefilter("ignore")

# обратите внимание, что Scikit-Learn импортируется как sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn import metrics

from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score

# %%
def add_column_one(matrix):
    ones = np.ones((matrix.shape[0], 1))
    return(np.concatenate((ones, matrix), axis=1))

# %%
class RidgeRegression:
    def __init__(self, lambd=0.1):
        '''
        Инициализация модели.
        
        Аргументы:
        lambd -- параметр регуляризации.
        '''
        
        self.lambd = lambd
        self.theta=0
        
    def fit(self,X, Y):
        '''
        Обучение модели ridge-регрессии.
        
        Аргументы:
        X -- numpy матрица объект-признак размера (n, d);
        Y -- numpy вектор значений целевого признака размера (n,).
        '''
        X=add_column_one(X)
        self.theta=np.linalg.inv(np.transpose(X)@X+ self.lambd*np.eye(X.shape[1]))@np.transpose(X)@Y
        
        return self
    
    def predict(self,X):
        '''
        Вычисление предсказаний.
        
        Аргументы:
        X -- numpy матрица объект-признак размера (n, d);
        
        Возвращает:
        predictions -- предсказания в виде numpy вектора размера (n,).
        '''
        X=add_column_one(X)
        predictions=X@self.theta
        
        return predictions
    def give_theta(self):
        return self.theta

# %% [markdown]
# Разделите данные на три части &mdash; обучающую, валидационную и тестовую в соотношении 3:1:1. На первой из них вам необходимо проводить всю аналитику и обучать все модели &mdash; регрессию, скалирование и т.д.. Вторую вы будете использовать для выбора оптимального значения гиперпараметра. Наконец, тестовую выборку необходимо использовать только для вычисления итогового значения метрик выбранной модели. Именно эти числа вам нужно говорить заказчику.

# %%
data = pd.read_csv('day.csv', parse_dates=[0])[['season', 'mnth', 'holiday', 'weekday', 'workingday',
                                                'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt']]
columns_names=data.columns

# %%
train, test = train_test_split(data, test_size=0.2)
train, val = train_test_split(train, test_size=0.25)

categorial_features = ['season', 'mnth', 'holiday','weekday','workingday','weathersit']  # категориальные признаки
real_features = ['temp', 'atemp', 'hum','windspeed']  # вещественные признаки
target_feature = 'cnt'  # целевой признакa

# %% [markdown]
# Выполните необходимые преобразования признаков. Не забудьте, что обучить преобразования нужно только по обучающей выборке.

# %% [markdown]
# Надо сделать стандартизацию (так как у нас могут быть разные единицы измерения и в прошлом задании я писал, зачем нам необходимо это делать)
# будем использовать MinMaxScaler
# наш план:стандартизировать все признаки, таргет признак не трогать, но при этом на train части я буду делать fit_transform, в то время, как на val and test только transform буду делать

# %%
from sklearn.preprocessing import MinMaxScaler
trans = MinMaxScaler()
train[categorial_features+real_features] = trans.fit_transform(train[categorial_features+real_features])
#затем нам надо стандартизировать данные в val and test на основе trans.fit(train)
val[categorial_features+real_features] = trans.transform(val[categorial_features+real_features])
test[categorial_features+real_features] = trans.transform(test[categorial_features+real_features])

# %%
encoder = OneHotEncoder(drop='first', sparse=False)

train_cat = encoder.fit_transform(train[categorial_features])
X_train = np.hstack([train[real_features], train_cat])

val_cat = encoder.fit_transform(val[categorial_features])
X_val = np.hstack([val[real_features], val_cat])

# %% [markdown]
# Определите сетку значений гиперпараметра $\lambda$ и обучите для каждого значения сетки модель ridge-регрессии. Обычно эффективнее брать сетку в логарифмическом масштабе.

# %%
lambd=np.logspace(-5,5,50)
all_ridge_regression=[RidgeRegression(i) for i in lambd]
all_ridge_regression=np.array(all_ridge_regression)
for i in range(len(all_ridge_regression)):
    all_ridge_regression[i]=all_ridge_regression[i].fit(X_train, train[target_feature])

# %% [markdown]
# Для каждой из них посчитайте ошибку по метрикам RMSE, MAE, MAPE по обучающей и валидационной выборкам.

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return 100 * (np.abs(y_true - y_pred) / y_true).mean()

RMSE_train_all=np.empty(len(all_ridge_regression))
MAE_train_all=np.empty(len(all_ridge_regression))
MAPE_train_all=np.empty(len(all_ridge_regression))

RMSE_val_all=np.empty(len(all_ridge_regression))
MAE_val_all=np.empty(len(all_ridge_regression))
MAPE_val_all=np.empty(len(all_ridge_regression))

for i, ridge_regression_now in enumerate(all_ridge_regression):
    train_preds=ridge_regression_now.predict(X_train)
    val_preds=ridge_regression_now.predict(X_val)
    
    RMSE_train_all[i]=metrics.mean_squared_error(train[target_feature], train_preds) ** 0.5
    MAE_train_all[i]=metrics.mean_absolute_error(train[target_feature], train_preds)
    MAPE_train_all[i]=mean_absolute_percentage_error(train[target_feature], train_preds)
    
    RMSE_val_all[i]=metrics.mean_squared_error(val[target_feature], val_preds) ** 0.5
    MAE_val_all[i]=metrics.mean_absolute_error(val[target_feature], val_preds)
    MAPE_val_all[i]=mean_absolute_percentage_error(val[target_feature], val_preds)

# %% [markdown]
# Для каждой метрики постройте графики зависимости значений метрики от значения гиперпараметра. Сравните поведение значений метрик для обучающей и валидационной выборок.

# %% [markdown]
# Постройте также на одном графике кривые зависимости значений оценок коэффициентов от значений гиперпараметра. Какая наблюдается зависимость? Как вы это можете охарактеризовать?

# %%
fig,axs = plt.subplots(3, 1,figsize=(20,15),sharex=True)

axs[0].plot(lambd,RMSE_train_all,label = "RMSE_train")
axs[0].plot(lambd,RMSE_val_all,label = "RMSE_val")
axs[0].set_title("Зависимость значений метрики RMSE от значения гиперпараметра для обучающей и валидационной выборок")

axs[1].plot(lambd,RMSE_train_all,label = "MAE_train")
axs[1].plot(lambd,RMSE_val_all,label = "MAE_val")
axs[1].set_title("Зависимость значений метрики MAE от значения гиперпараметра для обучающей и валидационной выборок")

axs[2].plot(lambd,MAPE_train_all,label = "MAPE_train")
axs[2].plot(lambd,MAPE_val_all,label = "MAPE_val")
axs[2].set_title("Зависимость значений метрики MAPE от значения гиперпараметра для обучающей и валидационной выборок")
plt.xscale('log')
plt.xlabel('$\lambda$')
for i in range (3):
    axs[i].legend()

# %%
plt.figure(figsize=(20, 11))
theta_all=[]
for i,all_ridge_regression_now in enumerate(all_ridge_regression):
    theta_all.append(all_ridge_regression_now.theta)
    
theta_all=np.array(theta_all)
for i in range(28):
    plt.plot(lambd,theta_all[:,i], label='Коэффициент {}'.format(i+1))
    
plt.legend()
plt.title("Зависимость значений оценок коэффициентов от значений гиперпараметра")
plt.xscale('log')
plt.xlabel('$\lambda$');

# %% [markdown]
# Выберите оптимальное значение гиперпараметра и посчитайте ошибку на тестовой выборке.

# %% [markdown]
# Нам надо найти оптимальный гиперпараметр, то есть нам надо найти такой гиперпараметр, чтобы метрики были еще довольно хорошими, но при этом гиперпараметр не должен быть оч маленьким, иначе коэффициент $\lambda\cdot|\theta|^2$ будет зануляться, а нам это наооборот это не надо

# %%
test_cat = encoder.fit_transform(test[categorial_features])
X_test = np.hstack([test[real_features], test_cat])

best_ridge_regression=RidgeRegression(70)
best_ridge_regression.fit(X_train, train[target_feature])

test_preds=best_ridge_regression.predict(X_test)

RMSE=metrics.mean_squared_error(test[target_feature], test_preds) ** 0.5
MAE=metrics.mean_absolute_error(test[target_feature], test_preds)
MAPE=mean_absolute_percentage_error(test[target_feature], test_preds)

print(f"RMSE={RMSE}")
print(f"MAE={MAE}")
print(f"MAPE={MAPE}")
# Out:
# RMSE=1530.8330190044624
# MAE=1245.6178759227882
# MAPE=31.390079798462427

# %% [markdown]
# Если посмотреть внимательно на графики сверху, то хорошо видно, что при маленьких $\lambda$ метрики почти не меняются. Но при этом нам нельзя брать оч маленькие $\lambda$ (уже писал выше, так как тогда нужный нам коэффициент будет обнуляться). Но при этом при больших $\lambda$ растет ошибка (смотрим на графики с метриками), так что нужно находить золотую середину между процентов ошибки и величиной коэффициентов.

# %% [markdown]
# *Вывод*: когда в прошлой задаче (легкая часть) мы работали с этими данными, мы запомнили, что у нас было слишком много зависимых между собой данных, которые портили нам картину. В этой задаче мы поняли, что нам выгодно использовать ridge-регрессию для того, чтобы понизить размерность данных и начать решать данную проблему

# %% [markdown]
# ### Задача 7.
#
# Предположим, что имеющиеся у нас данные по велопрокату &mdash; большие данные. Конечно же в реальности это не так. Однако, для простой учебной задачи это в самый раз, чтобы ничего ни у кого не подвисало.
#
# ![bigdata.jpg](attachment:bigdata.jpg)
#
# Выберите некоторое начальное приближение оценок коэффициентов, например, в начале координат.

# %%
theta_start=np.zeros(X_train.shape[1])

# %% [markdown]
# Реализуйте процедуру mini-batch стохастического градиентного спуска для поиска оценок коэффициентов в модели ridge-регрессии. Размер батча обычно берут кратно степени двойки, например, 128 или 256.

# %%
def step_in_mini_batch(X,Y,theta,eta_speed,lambd,size_batch=128):
    list_of_strings = sps.randint.rvs(0, X.shape[0], size=size_batch)
    
    new_X=[X[list_of_strings[i]] for i in range(size_batch)]
    new_X=np.array(new_X)
    new_Y=[Y[list_of_strings[i]] for i in range(size_batch)]
    new_Y=np.array(new_Y)
    
    coefficient_for_new_theta=np.transpose(new_X)@(new_X@theta-new_Y)
    new_theta=theta-eta_speed*coefficient_for_new_theta+lambd*theta
    #print(new_theta)
    return new_theta

# %%
def mini_batch_list(X,Y,theta,eta_speed,lambd,size_batch=128,max_steps=130):
    all_theta=list()
    new_theta=theta
    
    for i in range(max_steps):
        new_theta=step_in_mini_batch(X,Y,new_theta,eta_speed,lambd,size_batch)
        all_theta.append(new_theta)
    return np.array(all_theta)

# %%
#также нам потрубется еще функция predict для дальнейшего задания
def predict_theta(X,theta):
    return X@theta

# %% [markdown]
# Нарисуйте графики зависимости значений метрик RMSE, MAE, MAPE от номера итерации для обучающей и валидационной выборок. Сколько итераций пришлось совершить?

# %%
all_theta=mini_batch_list(X_train,train[target_feature].to_numpy(),theta_start,eta_speed=0.001,lambd=0.007)

# %%
RMSE_train_all=np.empty(len(all_theta))
MAE_train_all=np.empty(len(all_theta))
MAPE_train_all=np.empty(len(all_theta))

RMSE_val_all=np.empty(len(all_theta))
MAE_val_all=np.empty(len(all_theta))
MAPE_val_all=np.empty(len(all_theta))

for i, theta_now in enumerate(all_theta):
    train_preds=predict_theta(X_train,theta_now)
    val_preds=predict_theta(X_val,theta_now)
    
    RMSE_train_all[i]=metrics.mean_squared_error(train[target_feature], train_preds) ** 0.5
    MAE_train_all[i]=metrics.mean_absolute_error(train[target_feature], train_preds)
    MAPE_train_all[i]=mean_absolute_percentage_error(train[target_feature], train_preds)
    
    RMSE_val_all[i]=metrics.mean_squared_error(val[target_feature], val_preds) ** 0.5
    MAE_val_all[i]=metrics.mean_absolute_error(val[target_feature], val_preds)
    MAPE_val_all[i]=mean_absolute_percentage_error(val[target_feature], val_preds)

# %%
fig,axs = plt.subplots(3, 1,figsize=(20,15),sharex=True)

all_steps=np.array([i for i in range(len(all_theta))])

axs[0].plot(all_steps,RMSE_train_all,label = "RMSE_train")
axs[0].plot(all_steps,RMSE_val_all,label = "RMSE_val")
axs[0].set_title("Зависимость значений метрики RMSE от номера итерации для обучающей и валидационной выборок")

axs[1].plot(all_steps,RMSE_train_all,label = "MAE_train")
axs[1].plot(all_steps,RMSE_val_all,label = "MAE_val")
axs[1].set_title("Зависимость значений метрики MAE от номера итерации для обучающей и валидационной выборок")

axs[2].plot(all_steps,MAPE_train_all,label = "MAPE_train")
axs[2].plot(all_steps,MAPE_val_all,label = "MAPE_val")
axs[2].set_title("Зависимость значений метрики MAPE от номера итерации для обучающей и валидационной выборок")

plt.xlabel('Номер шага в градиентном спуске')
for i in range (3):
    axs[i].legend()

# %% [markdown]
# Посчитайте ошибку на тестовой выборке.

# %%
#перестает меняться уже где-то около 120
best_theta=all_theta[120]
test_preds=predict_theta(X_test,best_theta)

RMSE=metrics.mean_squared_error(test[target_feature], test_preds) ** 0.5
MAE=metrics.mean_absolute_error(test[target_feature], test_preds)
MAPE=mean_absolute_percentage_error(test[target_feature], test_preds)

print(f"RMSE={RMSE}")
print(f"MAE={MAE}")
print(f"MAPE={MAPE}")
# Out:
# RMSE=1516.792513047926
# MAE=1299.9564864982758
# MAPE=32.1089027041416

# %% [markdown]
# Сделайте выводы.

# %% [markdown]
# На самом деле результат близок к результату прошлого номера (обычной гребневой регрессии). Понятно, что после какого-то шага мы можем закончить спуск, так как изменения метрик будут меньше какого-то эпсилона (почти не будут меняться), и мы сможем зафиксировать результат. У нас этот шаг около 120. Также этот метод удобен при работе с большими данными (как мы увидели на данном примере)
